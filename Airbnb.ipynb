# %%
import pandas as pd
import pickle
from sklearn.externals import joblib
from pandas.api.types import is_string_dtype,is_numeric_dtype,is_int64_dtype
from sklearn import preprocessing
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix,accuracy_score,matthews_corrcoef,f1_score
from sklearn.externals import joblib
from matplotlib import pyplot as plt
import seaborn as sns

#from xgboost import XGBClassifier
import category_encoders as ce

# %matplotlib inline

# %%
# %pwd
# Out:
# '/Users/meng/Desktop/NEU-Courses/6105-DataSciEngMethods/Final-project/airbnb-recruiting-new-user-bookings'

# %%
my_path = '/Users/meng/Desktop/NEU-Courses/6105-DataSciEngMethods/Final-project/airbnb-recruiting-new-user-bookings'

# %%
mydf_train = pd.read_csv(f'{my_path}/train_users_2.csv',parse_dates = ["date_account_created"])
print(mydf_train.shape)
mydf_train.head(3)
# Out:
# (213451, 16)
#            id date_account_created  timestamp_first_active date_first_booking  \
# 0  gxn3p5htnn           2010-06-28          20090319043255                NaN
# 1  820tgsjxq7           2011-05-25          20090523174809                NaN
# 2  4ft3gnwmtx           2010-09-28          20090609231247         2010-08-02
#
#       gender   age signup_method  signup_flow language affiliate_channel  \
# 0  -unknown-   NaN      facebook            0       en            direct
# 1       MALE  38.0      facebook            0       en               seo
# 2     FEMALE  56.0         basic            3       en            direct
#
#   affiliate_provider first_affiliate_tracked signup_app first_device_type  \
# 0             direct               untracked        Web       Mac Desktop
# 1             google               untracked        Web       Mac Desktop
# 2             direct               untracked        Web   Windows Desktop
#
#   first_browser country_destination
# 0        Chrome                 NDF
# 1        Chrome                 NDF
# 2            IE                  US

# %%
mydf_train.rename(columns={'country_destination': 'country'}, inplace=True) # rename country column

# %%
mydf_train.head(2)
# Out:
#            id date_account_created  timestamp_first_active date_first_booking  \
# 0  gxn3p5htnn           2010-06-28          20090319043255                NaN
# 1  820tgsjxq7           2011-05-25          20090523174809                NaN
#
#       gender   age signup_method  signup_flow language affiliate_channel  \
# 0  -unknown-   NaN      facebook            0       en            direct
# 1       MALE  38.0      facebook            0       en               seo
#
#   affiliate_provider first_affiliate_tracked signup_app first_device_type  \
# 0             direct               untracked        Web       Mac Desktop
# 1             google               untracked        Web       Mac Desktop
#
#   first_browser country
# 0        Chrome     NDF
# 1        Chrome     NDF

# %%
country_lookup = dict(zip(mydf_train['country'].astype('category').cat.codes + 1,
                          mydf_train['country']))

# %%
country_lookup
# Out:
# {8: 'NDF',
#  11: 'US',
#  12: 'other',
#  5: 'FR',
#  2: 'CA',
#  6: 'GB',
#  4: 'ES',
#  7: 'IT',
#  10: 'PT',
#  9: 'NL',
#  3: 'DE',
#  1: 'AU'}

# %% [markdown]
# #### Plot to view percentage of bookings for each destination

# %%
sns.set_style()
destn_countries = mydf_train.country.value_counts(dropna = False) / mydf_train.shape[0] * 100
destn_countries.plot('bar', rot = 0)
plt.xlabel('Destination country')
plt.ylabel('Percentage of booking')
# Out:
# Text(0, 0.5, 'Percentage of booking')

# %% [markdown]
# #### Plot to view the percentage of missing values for each feature

# %%
null_vals = mydf_train.isnull().sum()/len(mydf_train)*100
null_vals = pd.DataFrame(null_vals)
null_vals.reset_index(inplace = True)
null_vals.columns = ["Feature","Percent missing"]
plt.figure(figsize = (8,6))
plt.xticks(rotation=45)
sns.barplot(x = "Percent missing",y ="Feature",data = null_vals,orient = "h")

# %%
# Drop column date_first_booking as it has more than 80% of null values
mydf_train2 = mydf_train.drop("date_first_booking",axis = 1)
print(mydf_train2.shape)
mydf_train2.head(2)
# Out:
# (213451, 15)
#            id date_account_created  timestamp_first_active     gender   age  \
# 0  gxn3p5htnn           2010-06-28          20090319043255  -unknown-   NaN
# 1  820tgsjxq7           2011-05-25          20090523174809       MALE  38.0
#
#   signup_method  signup_flow language affiliate_channel affiliate_provider  \
# 0      facebook            0       en            direct             direct
# 1      facebook            0       en               seo             google
#
#   first_affiliate_tracked signup_app first_device_type first_browser country
# 0               untracked        Web       Mac Desktop        Chrome     NDF
# 1               untracked        Web       Mac Desktop        Chrome     NDF

# %%
#Sorting values by date_account_created
mydf_sorted_train2=mydf_train2.sort_values(by='date_account_created')
mydf_sorted_train2.head(10)
# Out:
#             id date_account_created  timestamp_first_active     gender   age  \
# 5   osr2jwljor           2010-01-01          20100101215619  -unknown-   NaN
# 6   lsw9q7uk0j           2010-01-02          20100102012558     FEMALE  46.0
# 7   0d01nltbrs           2010-01-03          20100103191905     FEMALE  47.0
# 9   6uh8zyj2gn           2010-01-04          20100104023758  -unknown-  46.0
# 8   a1vcnhxeij           2010-01-04          20100104004211     FEMALE  50.0
# 10  yuuqmid2rp           2010-01-04          20100104194251     FEMALE  36.0
# 13  dy3rgx56cu           2010-01-05          20100105083259     FEMALE  37.0
# 11  om1ss59ys8           2010-01-05          20100105051812     FEMALE  47.0
# 12  k6np330cm1           2010-01-05          20100105060859  -unknown-   NaN
# 16  2dwbwkx056           2010-01-07          20100107215125  -unknown-   NaN
#
#    signup_method  signup_flow language affiliate_channel affiliate_provider  \
# 5          basic            0       en             other              other
# 6          basic            0       en             other         craigslist
# 7          basic            0       en            direct             direct
# 9          basic            0       en             other         craigslist
# 8          basic            0       en             other         craigslist
# 10         basic            0       en             other         craigslist
# 13         basic            0       en             other         craigslist
# 11         basic            0       en             other         craigslist
# 12         basic            0       en            direct             direct
# 16         basic            0       en             other         craigslist
#
#    first_affiliate_tracked signup_app first_device_type first_browser country
# 5                      omg        Web       Mac Desktop        Chrome      US
# 6                untracked        Web       Mac Desktop        Safari      US
# 7                      omg        Web       Mac Desktop        Safari      US
# 9                      omg        Web       Mac Desktop       Firefox      US
# 8                untracked        Web       Mac Desktop        Safari      US
# 10               untracked        Web       Mac Desktop       Firefox      US
# 13                  linked        Web       Mac Desktop       Firefox     NDF
# 11               untracked        Web            iPhone     -unknown-     NDF
# 12                     NaN        Web     Other/Unknown     -unknown-      FR
# 16                     NaN        Web     Other/Unknown     -unknown-     NDF

# %%
mydf_sorted_train2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 213451 entries, 5 to 213450
# Data columns (total 15 columns):
# id                         213451 non-null object
# date_account_created       213451 non-null datetime64[ns]
# timestamp_first_active     213451 non-null int64
# gender                     213451 non-null object
# age                        125461 non-null float64
# signup_method              213451 non-null object
# signup_flow                213451 non-null int64
# language                   213451 non-null object
# affiliate_channel          213451 non-null object
# affiliate_provider         213451 non-null object
# first_affiliate_tracked    207386 non-null object
# signup_app                 213451 non-null object
# first_device_type          213451 non-null object
# first_browser              213451 non-null object
# country                    213451 non-null object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(11)
# memory usage: 26.1+ MB

# %%
# Converting timestamp to datetime format
mydf_sorted_train2['timestamp_first_active'] = pd.to_datetime((mydf_sorted_train2.timestamp_first_active), format='%Y%m%d%H%M%S')

# %%
# Split timestamp 
mydf_sorted_train2['weekday_first_active'] = mydf_sorted_train2.timestamp_first_active.dt.weekday_name
mydf_sorted_train2['day_first_active'] = mydf_sorted_train2.timestamp_first_active.dt.day
mydf_sorted_train2['month_first_active'] = mydf_sorted_train2.timestamp_first_active.dt.month
mydf_sorted_train2['year_first_active'] = mydf_sorted_train2.timestamp_first_active.dt.year
mydf_sorted_train2['hour_first_active'] = mydf_sorted_train2.timestamp_first_active.dt.hour
mydf_sorted_train2['minute_first_active'] = mydf_sorted_train2.timestamp_first_active.dt.minute
mydf_sorted_train2['second_first_active'] = mydf_sorted_train2.timestamp_first_active.dt.second

# %%
# Drop timestamp after splitting it
mydf_sorted_train2 = mydf_sorted_train2.drop("timestamp_first_active",axis = 1)
print(mydf_sorted_train2.shape)
mydf_sorted_train2.head(2)
# Out:
# (213451, 21)
#            id date_account_created     gender   age signup_method  \
# 5  osr2jwljor           2010-01-01  -unknown-   NaN         basic
# 6  lsw9q7uk0j           2010-01-02     FEMALE  46.0         basic
#
#    signup_flow language affiliate_channel affiliate_provider  \
# 5            0       en             other              other
# 6            0       en             other         craigslist
#
#   first_affiliate_tracked         ...          first_device_type  \
# 5                     omg         ...                Mac Desktop
# 6               untracked         ...                Mac Desktop
#
#   first_browser country weekday_first_active day_first_active  \
# 5        Chrome      US               Friday                1
# 6        Safari      US             Saturday                2
#
#    month_first_active  year_first_active  hour_first_active  \
# 5                   1               2010                 21
# 6                   1               2010                  1
#
#    minute_first_active  second_first_active
# 5                   56                   19
# 6                   25                   58
#
# [2 rows x 21 columns]

# %%
#Check for total number of missing values
no_of_missing_values=mydf_sorted_train2.isnull().sum().sum()
no_of_missing_values
# Out:
# 94055

# %%
#Define functions
def split_dates(df,date_column):
    date_df = pd.DataFrame({"year": df[date_column].dt.year,
              "month": df[date_column].dt.month,
              "day": df[date_column].dt.day,
              "dayofyear": df[date_column].dt.dayofyear,
              "week": df[date_column].dt.week,
              "weekofyear": df[date_column].dt.weekofyear,
              "dayofweek": df[date_column].dt.dayofweek,
              "weekday": df[date_column].dt.weekday,
              "quarter": df[date_column].dt.quarter,
             })
    df = df.drop(date_column,axis = 1)
    df = pd.concat([df,date_df],axis = 1)
    return df

def str_to_cat(my_df):
    for p,q in my_df.items(): 
        if is_string_dtype(q): 
            my_df[p] = q.astype('category').cat.as_ordered()
    return my_df
def mydf_to_nums(my_df, content, label):
    if not is_numeric_dtype(content):
        my_df[label] = content.cat.codes + 1
        
def mydf_imputer(my_df, feature, null_status, null_table):
    if is_numeric_dtype(feature):
        if pd.isnull(feature).sum() or (null_status in null_table):
            filler = null_table[null_status] if null_status in null_table else feature.median()
            my_df[null_status] = feature.fillna(filler)
            null_table[null_status] = filler
    return null_table   

def mydf_preprocessor(my_df, null_table):
    '''null_table  = your table or None'''
    
    if null_table is None: 
        null_table = dict()
    for p,q in my_df.items(): 
        null_table = mydf_imputer(my_df, q, p, null_table)
    for label,content in my_df.items(): 
        mydf_to_nums(my_df, content, label)
    my_df = pd.get_dummies(my_df, dummy_na = True)
    res = [my_df, null_table]
    return res

# %%
#Split "date_account_created" using the split_dates method defined in the previous step
mydf_sorted_train3 = split_dates(mydf_sorted_train2,"date_account_created")
print(mydf_sorted_train3.shape)
# Out:
# (213451, 29)

# %%
print(mydf_sorted_train3.shape)
# Out:
# (213451, 29)

# %%
mydf_sorted_train3.iloc[:,1:] = str_to_cat(mydf_sorted_train3.iloc[:,1:]) # exclude id column
print(mydf_sorted_train3.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 213451 entries, 5 to 213450
# Data columns (total 29 columns):
# id                         213451 non-null object
# gender                     213451 non-null category
# age                        125461 non-null float64
# signup_method              213451 non-null category
# signup_flow                213451 non-null int64
# language                   213451 non-null category
# affiliate_channel          213451 non-null category
# affiliate_provider         213451 non-null category
# first_affiliate_tracked    207386 non-null category
# signup_app                 213451 non-null category
# first_device_type          213451 non-null category
# first_browser              213451 non-null category
# country                    213451 non-null category
# weekday_first_active       213451 non-null category
# day_first_active           213451 non-null int64
# month_first_active         213451 non-null int64
# year_first_active          213451 non-null int64
# hour_first_active          213451 non-null int64
# minute_first_active        213451 non-null int64
# second_first_active        213451 non-null int64
# year                       213451 non-null int64
# month                      213451 non-null int64
# day                        213451 non-null int64
# dayofyear                  213451 non-null int64
# week                       213451 non-null int64
# weekofyear                 213451 non-null int64
# dayofweek                  213451 non-null int64
# weekday                    213451 non-null int64
# quarter                    213451 non-null int64
# dtypes: category(11), float64(1), int64(16), object(1)
# memory usage: 33.2+ MB
# None

# %%
mydf_sorted_train4 = str_to_cat(mydf_sorted_train3)
print(mydf_sorted_train4.shape)
mydf_sorted_train4.head(3)
# Out:
# (213451, 29)
#            id     gender   age signup_method  signup_flow language  \
# 5  osr2jwljor  -unknown-   NaN         basic            0       en
# 6  lsw9q7uk0j     FEMALE  46.0         basic            0       en
# 7  0d01nltbrs     FEMALE  47.0         basic            0       en
#
#   affiliate_channel affiliate_provider first_affiliate_tracked signup_app  \
# 5             other              other                     omg        Web
# 6             other         craigslist               untracked        Web
# 7            direct             direct                     omg        Web
#
#     ...    second_first_active  year month day  dayofyear  week  weekofyear  \
# 5   ...                     19  2010     1   1          1    53          53
# 6   ...                     58  2010     1   2          2    53          53
# 7   ...                      5  2010     1   3          3    53          53
#
#    dayofweek  weekday  quarter
# 5          4        4        1
# 6          5        5        1
# 7          6        6        1
#
# [3 rows x 29 columns]

# %%
mydf_sorted_train4.iloc[:,1:]
# Out:
#            gender   age signup_method  signup_flow language affiliate_channel  \
# 5       -unknown-   NaN         basic            0       en             other
# 6          FEMALE  46.0         basic            0       en             other
# 7          FEMALE  47.0         basic            0       en            direct
# 9       -unknown-  46.0         basic            0       en             other
# 8          FEMALE  50.0         basic            0       en             other
# 10         FEMALE  36.0         basic            0       en             other
# 13         FEMALE  37.0         basic            0       en             other
# 11         FEMALE  47.0         basic            0       en             other
# 12      -unknown-   NaN         basic            0       en            direct
# 16      -unknown-   NaN         basic            0       en             other
# 15         FEMALE  33.0         basic            0       en            direct
# 14         FEMALE  36.0         basic            0       en             other
# 17      -unknown-  31.0         basic            0       en             other
# 18      -unknown-   NaN         basic            0       en               seo
# 21           MALE  30.0         basic            0       en            direct
# 20      -unknown-   NaN         basic            0       en            direct
# 19         FEMALE  29.0         basic            0       en            direct
# 23      -unknown-   NaN         basic            0       en             other
# 24         FEMALE  40.0         basic            0       en               seo
# 22      -unknown-  40.0         basic            0       en               seo
# 25         FEMALE  26.0         basic            0       en             other
# 26      -unknown-   NaN         basic            0       en             other
# 27         FEMALE  32.0         basic            0       en             other
# 29      -unknown-  37.0         basic            0       en            direct
# 28      -unknown-  35.0         basic            0       en            direct
# 33           MALE  29.0         basic            0       en             other
# 32      -unknown-  31.0         basic            0       en               seo
# 30      -unknown-  42.0         basic            0       en             other
# 31           MALE  31.0         basic            0       en            direct
# 36         FEMALE  31.0         basic            0       en            direct
# ...           ...   ...           ...          ...      ...               ...
# 213070  -unknown-  41.0         basic           25       ko            direct
# 213064       MALE  31.0         basic            0       en            direct
# 213071     FEMALE  35.0         basic            0       en            direct
# 213073  -unknown-   NaN         basic            0       en            direct
# 213074  -unknown-   NaN         basic            0       en            direct
# 213075       MALE  20.0      facebook            0       en            direct
# 213076       MALE  25.0      facebook            0       en         sem-brand
# 213077  -unknown-   NaN         basic            0       en            direct
# 213078  -unknown-   NaN         basic            0       en            direct
# 213072  -unknown-  26.0         basic            0       ko            direct
# 213063  -unknown-  25.0         basic            0       en            direct
# 213062  -unknown-   NaN         basic           25       en            direct
# 213061     FEMALE  66.0         basic            0       en         sem-brand
# 213046  -unknown-   NaN         basic            0       en            direct
# 213047  -unknown-   NaN         basic           25       en            direct
# 213048       MALE  38.0         basic            0       en         sem-brand
# 213049  -unknown-   NaN         basic            0       en            direct
# 213050     FEMALE  45.0         basic            0       en            direct
# 213051  -unknown-   NaN         basic           25       en            direct
# 213052     FEMALE  36.0      facebook            0       en         sem-brand
# 213053  -unknown-   NaN         basic            0       en            direct
# 213054  -unknown-   NaN         basic            0       en     sem-non-brand
# 213055       MALE  37.0      facebook            0       en            direct
# 213056       MALE  47.0      facebook            0       en         sem-brand
# 213057     FEMALE  29.0      facebook            0       en            direct
# 213058  -unknown-  19.0         basic            0       en            direct
# 213059  -unknown-   NaN         basic            0       en               seo
# 213060       MALE  22.0         basic            0       en            direct
# 213044     FEMALE  30.0      facebook            0       en            direct
# 213450  -unknown-   NaN         basic           25       en            direct
#
#        affiliate_provider first_affiliate_tracked signup_app  \
# 5                   other                     omg        Web
# 6              craigslist               untracked        Web
# 7                  direct                     omg        Web
# 9              craigslist                     omg        Web
# 8              craigslist               untracked        Web
# 10             craigslist               untracked        Web
# 13             craigslist                  linked        Web
# 11             craigslist               untracked        Web
# 12                 direct                     NaN        Web
# 16             craigslist                     NaN        Web
# 15                 direct               untracked        Web
# 14             craigslist               untracked        Web
# 17             craigslist                     NaN        Web
# 18               facebook                     NaN        Web
# 21                 direct                  linked        Web
# 20                 direct                     NaN        Web
# 19                 direct               untracked        Web
# 23             craigslist               untracked        Web
# 24                 google               untracked        Web
# 22                 google               untracked        Web
# 25             craigslist               untracked        Web
# 26                  other               untracked        Web
# 27             craigslist               untracked        Web
# 29                 direct               untracked        Web
# 28                 direct                     NaN        Web
# 33             craigslist                     NaN        Web
# 32                 google               untracked        Web
# 30             craigslist               untracked        Web
# 31                 direct                     NaN        Web
# 36                 direct                  linked        Web
# ...                   ...                     ...        ...
# 213070             direct               untracked        iOS
# 213064             direct               untracked      Moweb
# 213071             direct                  linked        Web
# 213073             direct                  linked        Web
# 213074             direct               untracked        Web
# 213075             direct                  linked        Web
# 213076             google                     omg        Web
# 213077             direct                  linked        Web
# 213078             direct               untracked        Web
# 213072             direct               untracked        Web
# 213063             direct                  linked        Web
# 213062             direct               untracked        iOS
# 213061             google                     omg        Web
# 213046             direct                  linked      Moweb
# 213047             direct               untracked        iOS
# 213048             google                     omg        Web
# 213049             direct                  linked      Moweb
# 213050             direct               untracked        Web
# 213051             direct               untracked        iOS
# 213052             google                     omg        Web
# 213053             direct                  linked      Moweb
# 213054             google                     omg        Web
# 213055             direct                  linked      Moweb
# 213056             google                     omg        Web
# 213057             direct                  linked      Moweb
# 213058             direct                  linked        Web
# 213059             google                  linked        Web
# 213060             direct               untracked        Web
# 213044             direct                  linked        Web
# 213450             direct               untracked        iOS
#
#        first_device_type   ...    second_first_active  year month  day  \
# 5            Mac Desktop   ...                     19  2010     1    1
# 6            Mac Desktop   ...                     58  2010     1    2
# 7            Mac Desktop   ...                      5  2010     1    3
# 9            Mac Desktop   ...                     58  2010     1    4
# 8            Mac Desktop   ...                     11  2010     1    4
# 10           Mac Desktop   ...                     51  2010     1    4
# 13           Mac Desktop   ...                     59  2010     1    5
# 11                iPhone   ...                     12  2010     1    5
# 12         Other/Unknown   ...                     59  2010     1    5
# 16         Other/Unknown   ...                     25  2010     1    7
# 15       Windows Desktop   ...                     55  2010     1    7
# 14                iPhone   ...                     20  2010     1    7
# 17         Other/Unknown   ...                     25  2010     1    7
# 18         Other/Unknown   ...                     41  2010     1    8
# 21           Mac Desktop   ...                     41  2010     1   10
# 20         Other/Unknown   ...                     20  2010     1   10
# 19           Mac Desktop   ...                     17  2010     1   10
# 23           Mac Desktop   ...                     15  2010     1   11
# 24           Mac Desktop   ...                      8  2010     1   11
# 22                iPhone   ...                     38  2010     1   11
# 25           Mac Desktop   ...                     44  2010     1   12
# 26         Other/Unknown   ...                     20  2010     1   12
# 27       Desktop (Other)   ...                     49  2010     1   12
# 29        Android Tablet   ...                     33  2010     1   13
# 28         Other/Unknown   ...                     50  2010     1   13
# 33         Other/Unknown   ...                      9  2010     1   14
# 32         Other/Unknown   ...                     26  2010     1   14
# 30           Mac Desktop   ...                     57  2010     1   14
# 31         Other/Unknown   ...                     57  2010     1   14
# 36           Mac Desktop   ...                     29  2010     1   15
# ...                  ...   ...                    ...   ...   ...  ...
# 213070              iPad   ...                     50  2014     6   30
# 213064            iPhone   ...                     10  2014     6   30
# 213071       Mac Desktop   ...                      3  2014     6   30
# 213073   Windows Desktop   ...                     40  2014     6   30
# 213074       Mac Desktop   ...                     13  2014     6   30
# 213075       Mac Desktop   ...                     57  2014     6   30
# 213076       Mac Desktop   ...                     19  2014     6   30
# 213077     Android Phone   ...                     59  2014     6   30
# 213078       Mac Desktop   ...                     16  2014     6   30
# 213072   Windows Desktop   ...                     39  2014     6   30
# 213063       Mac Desktop   ...                      7  2014     6   30
# 213062              iPad   ...                     12  2014     6   30
# 213061              iPad   ...                      5  2014     6   30
# 213046            iPhone   ...                     50  2014     6   30
# 213047            iPhone   ...                     48  2014     6   30
# 213048              iPad   ...                      7  2014     6   30
# 213049            iPhone   ...                     54  2014     6   30
# 213050       Mac Desktop   ...                     38  2014     6   30
# 213051            iPhone   ...                     25  2014     6   30
# 213052              iPad   ...                     36  2014     6   30
# 213053            iPhone   ...                     22  2014     6   30
# 213054   Windows Desktop   ...                     34  2014     6   30
# 213055            iPhone   ...                     59  2014     6   30
# 213056       Mac Desktop   ...                     42  2014     6   30
# 213057            iPhone   ...                     57  2014     6   30
# 213058   Windows Desktop   ...                     14  2014     6   30
# 213059       Mac Desktop   ...                     58  2014     6   30
# 213060       Mac Desktop   ...                      0  2014     6   30
# 213044       Mac Desktop   ...                     39  2014     6   30
# 213450            iPhone   ...                     24  2014     6   30
#
#         dayofyear  week  weekofyear  dayofweek  weekday  quarter
# 5               1    53          53          4        4        1
# 6               2    53          53          5        5        1
# 7               3    53          53          6        6        1
# 9               4     1           1          0        0        1
# 8               4     1           1          0        0        1
# 10              4     1           1          0        0        1
# 13              5     1           1          1        1        1
# 11              5     1           1          1        1        1
# 12              5     1           1          1        1        1
# 16              7     1           1          3        3        1
# 15              7     1           1          3        3        1
# 14              7     1           1          3        3        1
# 17              7     1           1          3        3        1
# 18              8     1           1          4        4        1
# 21             10     1           1          6        6        1
# 20             10     1           1          6        6        1
# 19             10     1           1          6        6        1
# 23             11     2           2          0        0        1
# 24             11     2           2          0        0        1
# 22             11     2           2          0        0        1
# 25             12     2           2          1        1        1
# 26             12     2           2          1        1        1
# 27             12     2           2          1        1        1
# 29             13     2           2          2        2        1
# 28             13     2           2          2        2        1
# 33             14     2           2          3        3        1
# 32             14     2           2          3        3        1
# 30             14     2           2          3        3        1
# 31             14     2           2          3        3        1
# 36             15     2           2          4        4        1
# ...           ...   ...         ...        ...      ...      ...
# 213070        181    27          27          0        0        2
# 213064        181    27          27          0        0        2
# 213071        181    27          27          0        0        2
# 213073        181    27          27          0        0        2
# 213074        181    27          27          0        0        2
# 213075        181    27          27          0        0        2
# 213076        181    27          27          0        0        2
# 213077        181    27          27          0        0        2
# 213078        181    27          27          0        0        2
# 213072        181    27          27          0        0        2
# 213063        181    27          27          0        0        2
# 213062        181    27          27          0        0        2
# 213061        181    27          27          0        0        2
# 213046        181    27          27          0        0        2
# 213047        181    27          27          0        0        2
# 213048        181    27          27          0        0        2
# 213049        181    27          27          0        0        2
# 213050        181    27          27          0        0        2
# 213051        181    27          27          0        0        2
# 213052        181    27          27          0        0        2
# 213053        181    27          27          0        0        2
# 213054        181    27          27          0        0        2
# 213055        181    27          27          0        0        2
# 213056        181    27          27          0        0        2
# 213057        181    27          27          0        0        2
# 213058        181    27          27          0        0        2
# 213059        181    27          27          0        0        2
# 213060        181    27          27          0        0        2
# 213044        181    27          27          0        0        2
# 213450        181    27          27          0        0        2
#
# [213451 rows x 28 columns]

# %%
mydf_sorted_train4,my_table = mydf_preprocessor(mydf_sorted_train4.iloc[:,1:],null_table = None)
print(mydf_sorted_train4.shape)
mydf_sorted_train4.head(3)
# Out:
# (213451, 28)
#    gender   age  signup_method  signup_flow  language  affiliate_channel  \
# 5       1  34.0              1            0         6                  4
# 6       2  46.0              1            0         6                  4
# 7       2  47.0              1            0         6                  3
#
#    affiliate_provider  first_affiliate_tracked  signup_app  first_device_type  \
# 5                  13                        4           3                  4
# 6                   3                        7           3                  4
# 7                   5                        4           3                  4
#
#     ...     second_first_active  year  month  day  dayofyear  week  \
# 5   ...                      19  2010      1    1          1    53
# 6   ...                      58  2010      1    2          2    53
# 7   ...                       5  2010      1    3          3    53
#
#    weekofyear  dayofweek  weekday  quarter
# 5          53          4        4        1
# 6          53          5        5        1
# 7          53          6        6        1
#
# [3 rows x 28 columns]

# %%
my_table
# Out:
# {'age': 34.0}

# %%
#Checking missing values after imputation
no_of_missing_values=mydf_sorted_train4.isnull().sum().sum()
no_of_missing_values
# Out:
# 0

# %%
my_table
# Out:
# {'age': 34.0}

# %%
'''Now, let's separate the X and Y variables (vertical split of the dataframe). 
Here the Y column is the variable we are trying to predict - destination of the country'''

Y = mydf_sorted_train4["country"]
X = mydf_sorted_train4.drop(["country"],axis = 1)

print(X.shape,Y.shape)
# Out:
# (213451, 27) (213451,)

# %%
#Split training data as training set and validation set

def mydf_train_splitter(my_df_train,num_rows):
    return my_df_train[:num_rows].copy(),my_df_train[num_rows:]

X_train,X_valid = mydf_train_splitter(X,153451)
Y_train,Y_valid = mydf_train_splitter(Y,153451)

print(X_train.shape,X_valid.shape,Y_train.shape,Y_valid.shape)
# Out:
# (153451, 27) (60000, 27) (153451,) (60000,)

# %%
#Function to create a model for DNN

from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
seed = 1

# Function to create model
def create_model():
     # create model
    model = Sequential()
    model.add(Dense(35, input_dim=27, activation='relu'))
    model.add(Dense(20, activation='relu'))
    model.add(Dense(12, activation='relu'))
    
    # Compile model
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model
# Out:
# Using TensorFlow backend.

# %%
#Selecting 5 classifiers to test for better performance

from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.naive_bayes import GaussianNB
from keras.wrappers.scikit_learn import KerasClassifier

models = []

models.append(('KNN',KNeighborsClassifier(n_neighbors=20,weights='uniform')))
models.append(('Naive Bayes',GaussianNB()))
models.append(('DNN',KerasClassifier(build_fn=create_model, epochs=100, batch_size=100, verbose=False)))
models.append(('Random Forest',RandomForestClassifier(n_jobs = -1, n_estimators = 100,max_features = 0.5,random_state=1,
                               bootstrap = True)))
models.append(('XGBoost',XGBClassifier(max_depth=5, learning_rate=0.05, n_estimators=200,
                    objective='multi:softprob', subsample=0.5, colsample_bytree=0.5, seed=0)))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-42-86363d18584f> in <module>
#       2
#       3 from sklearn.ensemble import RandomForestClassifier
# ----> 4 from xgboost import XGBClassifier
#       5 from sklearn.naive_bayes import GaussianNB
#       6 from keras.wrappers.scikit_learn import KerasClassifier
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
#Fitting the model with all the 5 classifiers defined above

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

names = []
accuracy_scores = []
for name, model in models:
    model.fit(X_train,Y_train)
    Y_pred = model.predict(X_valid)
    accuracy_scores.append(accuracy_score(Y_valid,Y_pred))
    names.append(name)
    
DF = pd.DataFrame({'Name': names, 'Accuracy_Score': accuracy_scores})
print(DF)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-102cdc5ed06f> in <module>
#       6 names = []
#       7 accuracy_scores = []
# ----> 8 for name, model in models:
#       9     model.fit(X_train,Y_train)
#      10     Y_pred = model.predict(X_valid)
#
# NameError: name 'models' is not defined

# %%
# Plot Classifier accuracies

clf = sns.barplot(x = 'Name', y = 'Accuracy_Score', data = DF)
clf.set(xlabel='Classifier', ylabel='Accuracy')
for p in clf.patches:
    height = p.get_height()
    clf.text(p.get_x() + p.get_width()/2, height + 0.005, '{:1.3f}'.format(height), ha="center") 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-29c2e3c6ec28> in <module>
#       1 # Plot Classifier accuracies
#       2
# ----> 3 clf = sns.barplot(x = 'Name', y = 'Accuracy_Score', data = DF)
#       4 clf.set(xlabel='Classifier', ylabel='Accuracy')
#       5 for p in clf.patches:
#
# NameError: name 'DF' is not defined

# %% [markdown]
# #### As we can see, XGBoost performed better than all other classifiers. So, we fit our model using XGBoost

# %%
from xgboost import XGBClassifier
model_xgb = XGBClassifier(max_depth=5, learning_rate=0.05, n_estimators=200,
                    objective='multi:softprob', subsample=0.5, colsample_bytree=0.5, seed=0)                  
model_xgb.fit(X_train,Y_train)
Y_pred_xgb = model_xgb.predict(X_valid)
accuracy_score(Y_valid,Y_pred_xgb)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-45-d711768357ca> in <module>
# ----> 1 from xgboost import XGBClassifier
#       2 model_xgb = XGBClassifier(max_depth=5, learning_rate=0.05, n_estimators=200,
#       3                     objective='multi:softprob', subsample=0.5, colsample_bytree=0.5, seed=0)
#       4 model_xgb.fit(X_train,Y_train)
#       5 Y_pred_xgb = model_xgb.predict(X_valid)
#
# ModuleNotFoundError: No module named 'xgboost'

# %% [markdown]
# #### Plot Feature Selection

# %%
feat_imps = pd.DataFrame(model_xgb.feature_importances_, index = X_train.columns,
                                    columns=['Importance score']).sort_values('Importance score',ascending=False)
feat_imps = feat_imps.reset_index()
feat_imps.columns = ["Feature","Importance Score"]
plt.figure(figsize = (8,6))
sns.barplot(x = "Importance Score",y = "Feature",data = feat_imps,orient = "h")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-ae6e86c75123> in <module>
# ----> 1 feat_imps = pd.DataFrame(model_xgb.feature_importances_, index = X_train.columns,
#       2                                     columns=['Importance score']).sort_values('Importance score',ascending=False)
#       3 feat_imps = feat_imps.reset_index()
#       4 feat_imps.columns = ["Feature","Importance Score"]
#       5 plt.figure(figsize = (8,6))
#
# NameError: name 'model_xgb' is not defined

# %% [markdown]
# #### As it seems all features are important, we retain all features

# %% [markdown]
# ## Evaluating Test Set

# %%
'''Read in test data'''
my_test = pd.read_csv(f'{my_path}/test_users.csv',parse_dates = ["date_account_created"])

# %% [markdown]
# ### Follow the same steps of preprocessing for test set

# %%
my_test1 = my_test.drop("date_first_booking",axis = 1)

# %%
my_test1['timestamp_first_active'] = pd.to_datetime((my_test1.timestamp_first_active), format='%Y%m%d%H%M%S')

# %%
my_test1['weekday_first_active'] = str(my_test1.timestamp_first_active.dt.weekday_name)
my_test1['day_first_active'] = str(my_test1.timestamp_first_active.dt.day)
my_test1['month_first_active'] = str(my_test1.timestamp_first_active.dt.month)
my_test1['year_first_active'] = str(my_test1.timestamp_first_active.dt.year)
my_test1['hour_first_active'] = str(my_test1.timestamp_first_active.dt.hour)
my_test1['minute_first_active'] = str(my_test1.timestamp_first_active.dt.minute)
my_test1['second_first_active'] = str(my_test1.timestamp_first_active.dt.second)

# %%
my_test1.iloc[:,2:] = str_to_cat((my_test1.iloc[:,2:]))

# %%
my_test2 = my_test1.drop("timestamp_first_active",axis = 1)

# %%
my_test3 = split_dates(my_test2,"date_account_created")

# %%
my_test3.head(3)
# Out:
#            id     gender   age signup_method  signup_flow language  \
# 0  5uwns89zht     FEMALE  35.0      facebook            0       en
# 1  jtl0dijy2j  -unknown-   NaN         basic            0       en
# 2  xx0ulgorjt  -unknown-   NaN         basic            0       en
#
#   affiliate_channel affiliate_provider first_affiliate_tracked signup_app  \
# 0            direct             direct               untracked      Moweb
# 1            direct             direct               untracked      Moweb
# 2            direct             direct                  linked        Web
#
#     ...                                   second_first_active  year month day  \
# 0   ...     0         6\n1        51\n2        48\n3      ...  2014     7   1
# 1   ...     0         6\n1        51\n2        48\n3      ...  2014     7   1
# 2   ...     0         6\n1        51\n2        48\n3      ...  2014     7   1
#
#   dayofyear week weekofyear dayofweek weekday  quarter
# 0       182   27         27         1       1        3
# 1       182   27         27         1       1        3
# 2       182   27         27         1       1        3
#
# [3 rows x 28 columns]

# %%
my_test3.iloc[:,1:],my_table1 = mydf_preprocessor(my_test3.iloc[:,1:],null_table = my_table)
print(my_test3.shape)
my_test3.head(3)
print(my_table1)
# Out:
# (62096, 28)
# {'age': 34.0}

# %%
my_test3.iloc[:,1:].columns
# Out:
# Index(['gender', 'age', 'signup_method', 'signup_flow', 'language',
#        'affiliate_channel', 'affiliate_provider', 'first_affiliate_tracked',
#        'signup_app', 'first_device_type', 'first_browser',
#        'weekday_first_active', 'day_first_active', 'month_first_active',
#        'year_first_active', 'hour_first_active', 'minute_first_active',
#        'second_first_active', 'year', 'month', 'day', 'dayofyear', 'week',
#        'weekofyear', 'dayofweek', 'weekday', 'quarter'],
#       dtype='object')

# %%
'''Predictions for the test set'''
y_tst_pred = model_xgb.predict(my_test3.iloc[:,1:])
print(type(y_tst_pred))
# Out:
# <class 'numpy.ndarray'>

# %%
my_test3['country']= y_tst_pred

# %%
col_names = list(my_test3)
for col in col_names:
    my_test3[col] = my_test3[col].astype('category',copy=False)

# %%
#Replacing numeric values for country with initial string values
country_lookup = dict(zip(mydf_train['country'].astype('category').cat.codes + 1,
                          mydf_train['country']))

# %%
my_test3['country'] = my_test3['country'].replace(country_lookup)

# %%
my_test3.head(2)
# Out:
#            id gender   age signup_method signup_flow language  \
# 0  5uwns89zht      2  35.0             2           0        7
# 1  jtl0dijy2j      1  34.0             1           0        7
#
#   affiliate_channel affiliate_provider first_affiliate_tracked signup_app  \
# 0                 2                  5                       7          2
# 1                 2                  5                       7          2
#
#     ...    year month day dayofyear week weekofyear dayofweek weekday quarter  \
# 0   ...    2014     7   1       182   27         27         1       1       3
# 1   ...    2014     7   1       182   27         27         1       1       3
#
#   country
# 0     NDF
# 1     NDF
#
# [2 rows x 29 columns]

# %% [markdown]
# #### Extracting submission results to csv file

# %%
my_test3[['id','country']].to_csv("C:\\Users\\Soumya\\Documents\\NEU\\INFO6105\\airbnb-recruiting-new-user-bookings\\submission1.csv",index=False,header=True)
